# %% [markdown]
# # zombie_10of50_critique_fixed
#
# Fixed syntax error in critique logging string.

# %%
def safe_log(question_id, candidate, conf):
    msg = f"[{question_id}] candidate={candidate} conf={conf:.3f}"  # fixed string
    return msg

# Dummy predict stub for structural validity
def predict_stub():
    return {'answer': 0}
